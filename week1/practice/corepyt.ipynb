# %%
my = add_item(3)
my = add_item(5)
my = add_item(7)
print(my)
# Out:
# [7]

# %%
def add_item(x, lst=None):
    if lst is None:
        lst = []
    lst.append(x)
    return lst

my = add_item(3)
my = add_item(5)
my = add_item(7)
print(my)
# Out:
# [7]

# %%
def func(*args, **kwargs):
    s = sum(args)
    print(kwargs,s)

# %%
func(2,6,8,9,name="jc",role="dev")
# Out:
# {'name': 'jc', 'role': 'dev'} 25
